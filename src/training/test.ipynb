# %%
import pandas as pd

a = pd.read_csv("../../data/csv_files/field_f4")

a.describe()
# Out:
#                s_b          s_w          LAI          irr  temperature_2m  \
# count  3697.000000  3697.000000  3697.000000  3697.000000     3697.000000
# mean     24.121808    22.604939     1.188006     0.038431       14.345199
# std       3.652426     2.944436     0.896350     0.887344        4.645678
# min      15.410000    13.390000     0.000000     0.000000        3.000000
# 25%      22.710000    21.660000     0.249912     0.000000       10.800000
# 50%      24.560000    23.070000     1.670000     0.000000       14.200000
# 75%      26.427500    24.230000     1.800000     0.000000       17.500000
# max      31.360000    31.300000     2.840000    23.610000       27.000000
#
#        relative_humidity_2m  cloud_cover  wind_speed_10m  wind_direction_100m  \
# count           3697.000000  3697.000000     3697.000000          3697.000000
# mean              70.827157    41.683257        7.620476           183.669191
# ...

# %%
a = pd.read_csv("../../data/csv_files/field_f2")

a.describe()
# Out:
#                s_b          s_w          LAI          irr  temperature_2m  \
# count  3697.000000  3697.000000  3697.000000  3697.000000     3697.000000
# mean     22.669345    19.324451     1.292894     0.063664       14.345199
# std       3.982091     4.154420     1.094484     1.504817        4.645678
# min      13.870000    10.680000     0.000000     0.000000        3.000000
# 25%      20.290000    16.610000     0.081053     0.000000       10.800000
# 50%      23.860000    20.700000     1.320000     0.000000       14.200000
# 75%      25.570000    22.480000     2.380000     0.000000       17.500000
# max      29.950000    29.680000     2.890000    42.070000       27.000000
#
#        relative_humidity_2m  cloud_cover  wind_speed_10m  wind_direction_100m  \
# count           3697.000000  3697.000000     3697.000000          3697.000000
# mean              70.827157    41.683257        7.620476           183.669191
# ...
